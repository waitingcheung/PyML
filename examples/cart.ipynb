# %%
import sys
sys.path.insert(0, '..')

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

from lib.cart import DecisionTreeClassifier

# %%
X, y = load_iris(return_X_y=True)

# %%
# this classifier
model = DecisionTreeClassifier()
model.fit(X, y)
y_pred = model.predict(X)
accuracy_score(y, y_pred)
# Out:
# 1.0

# %%
# sklearn classifier
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf.fit(X, y)
accuracy_score(y, clf.predict(X))
# Out:
# 1.0

# %%
# plot the decision tree
fig, ax = plt.subplots(figsize=(16, 12))
tree.plot_tree(clf, filled=True, ax=ax)
# Out:
# [Text(446.4, 597.96, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(377.7230769230769, 489.24, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(515.0769230769231, 489.24, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(274.7076923076923, 380.52000000000004, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(137.35384615384615, 271.8, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(68.67692307692307, 163.07999999999998, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(206.03076923076924, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(412.0615384615385, 271.8, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(343.38461538461536, 163.07999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(480.73846153846154, 163.07999999999998, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(412.0615384615385, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(549.4153846153846, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(755.4461538461538, 380.52000000000004, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(686.7692307692307, 271.8, 'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(618.0923076923077, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(755.4461538461538, 163.07999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(824.123076923077, 271.8, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]
